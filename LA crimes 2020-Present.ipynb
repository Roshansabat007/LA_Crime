# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Crime_Data_from_2020_to_Present.csv')

# %%
df.shape
# Out:
# (1004847, 28)

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  200412582  09/09/2020 12:00:00 AM  09/09/2020 12:00:00 AM       630     4
#
#     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Wilshire          784         1     510
# 1     Central          182         1     330
# 2   Southwest          356         1     480
# 3    Van Nuys          964         1     343
# 4  Hollenbeck          413         1     510
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004847 entries, 0 to 1004846
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004847 non-null  int64
#  1   Date Rptd       1004847 non-null  object
#  2   DATE OCC        1004847 non-null  object
#  3   TIME OCC        1004847 non-null  int64
#  4   AREA            1004847 non-null  int64
#  5   AREA NAME       1004847 non-null  object
#  6   Rpt Dist No     1004847 non-null  int64
#  7   Part 1-2        1004847 non-null  int64
#  8   Crm Cd          1004847 non-null  int64
#  9   Crm Cd Desc     1004847 non-null  object
#  10  Mocodes         853256 non-null   object
#  11  Vict Age        1004847 non-null  int64
#  12  Vict Sex        860243 non-null   object
#  13  Vict Descent    860231 non-null   object
#  14  Premis Cd       1004831 non-null  float64
#  15  Premis Desc     1004259 non-null  object
# ...

# %%
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004847e+06  1.004847e+06  1.004847e+06  1.004847e+06  1.004847e+06
# mean   2.202171e+08  1.339911e+03  1.069147e+01  1.115607e+03  1.400307e+00
# std    1.318835e+07  6.510691e+02  6.110286e+00  6.111622e+02  4.899607e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106168e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209158e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311101e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521040e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.004847e+06  1.004847e+06  1.004831e+06   327193.000000  1.004836e+06
# mean   5.001353e+02  2.891905e+01  3.056073e+02      363.944543  4.998958e+02
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151591
# Vict Age                0
# Vict Sex           144604
# Vict Descent       144616
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677654
# Weapon Desc        677654
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935717
# Crm Cd 3          1002532
# Crm Cd 4          1004783
# LOCATION                0
# Cross Street       850626
# LAT                     0
# LON                     0
# dtype: int64

# %%
df['Part 1-2'].value_counts()
# Out:
# Part 1-2
# 1    602600
# 2    402247
# Name: count, dtype: int64

# %%
df['Vict Descent'].value_counts()
# Out:
# Vict Descent
# H    296365
# W    201424
# B    135810
# X    106659
# O     77996
# A     21336
# K      5990
# F      4838
# C      4631
# J      1586
# V      1193
# I      1015
# Z       577
# P       288
# U       221
# D        91
# L        77
# G        74
# S        58
# -         2
# Name: count, dtype: int64

# %%
#Filling up the missing values

df['Mocodes'].fillna('Unknown', inplace=True)
df['Mocodes'].isnull().sum()
# Out:
# 0

# %%
df['Vict Sex'].fillna('Unknown', inplace=True)

# %%
df['Vict Descent'].fillna('Unknown', inplace=True)

# %%
df['Premis Cd'].fillna(df['Premis Cd'].mode()[0], inplace=True)

# %%
df['Premis Desc'].fillna('Unknown', inplace=True)

# %%
df['Weapon Used Cd'].fillna(0, inplace=True)

# %%
df['Weapon Desc'].fillna('No weapon', inplace=True)

# %%
df['Status'].fillna(df['Status'].mode()[0], inplace=True)

# %%
df['Premis Cd'].fillna(df['Premis Cd'].mode()[0], inplace=True)

# %%
df['Crm Cd 1'].fillna(df['Crm Cd 1'].mode()[0], inplace=True)
df['Crm Cd 2'].fillna(0, inplace=True)
df['Crm Cd 3'].fillna(0, inplace=True)
df['Crm Cd 4'].fillna(0, inplace=True)

# %%
df['Cross Street'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# DR_NO             0
# Date Rptd         0
# DATE OCC          0
# TIME OCC          0
# AREA              0
# AREA NAME         0
# Rpt Dist No       0
# Part 1-2          0
# Crm Cd            0
# Crm Cd Desc       0
# Mocodes           0
# Vict Age          0
# Vict Sex          0
# Vict Descent      0
# Premis Cd         0
# Premis Desc       0
# Weapon Used Cd    0
# Weapon Desc       0
# Status            0
# Status Desc       0
# Crm Cd 1          0
# Crm Cd 2          0
# Crm Cd 3          0
# Crm Cd 4          0
# LOCATION          0
# Cross Street      0
# LAT               0
# LON               0
# dtype: int64

# %%
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'].str.split().str[0], format='%m/%d/%Y', errors='coerce')

# %%
df['Date Rptd'].head()
# Out:
# 0   2020-03-01
# 1   2020-02-09
# 2   2020-11-11
# 3   2023-05-10
# 4   2020-09-09
# Name: Date Rptd, dtype: datetime64[ns]

# %%
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'].str.split().str[0], format='%m/%d/%Y', errors='coerce')

# %%
df['DATE OCC'].head()
# Out:
# 0   2020-03-01
# 1   2020-02-08
# 2   2020-11-04
# 3   2020-03-10
# 4   2020-09-09
# Name: DATE OCC, dtype: datetime64[ns]

# %%
df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)
hours = df['TIME OCC'].str[:2].astype(int)
minutes = df['TIME OCC'].str[2:].astype(int)

df['DATETIME OCC'] = df['DATE OCC'] + pd.to_timedelta(hours, unit="h") + pd.to_timedelta(minutes, unit="m")

# %%
df['DATETIME OCC'].head()
# Out:
# 0   2020-03-01 21:30:00
# 1   2020-02-08 18:00:00
# 2   2020-11-04 17:00:00
# 3   2020-03-10 20:37:00
# 4   2020-09-09 06:30:00
# Name: DATETIME OCC, dtype: datetime64[ns]

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['Vict Age'].unique()
# Out:
# array([  0,  47,  19,  27,  23,  41,  50,  30,  21,  28,  40,  42,  43,
#         26,  36,  57,  78,  51,  52,  29,  46,  53,  22,  70,  45,  39,
#         62,  31,  37,  32,  34,  65,  60,  49,  38,  24,  35,  61,  67,
#         25,  33,  66,   7,  48,  59,  68,  63,  18,  80,  55,  64,  85,
#         73,  20,  74,  14,  82,  58,  10,  44,  15,  17,  81,  76,  56,
#         75,  54,  84,  16,  90,  79,  99,  77,  69,   2,   9,   4,  12,
#         72,  13,  88,  71,   8,  87,   6,   5,  11,  92,  94,  93,   3,
#         83,  89,  86,  91,  95,  97,  96,  98, 120,  -4,  -3,  -2,  -1],
#       dtype=int64)

# %%
df = df[(df["Vict Age"] > 0) & (df["Vict Age"] < 120)]

# %%
df['Vict Age'].unique()
# Out:
# array([47, 19, 27, 23, 41, 50, 30, 21, 28, 40, 42, 43, 26, 36, 57, 78, 51,
#        52, 29, 46, 53, 22, 70, 45, 39, 62, 31, 37, 32, 34, 65, 60, 49, 38,
#        24, 35, 61, 67, 25, 33, 66,  7, 48, 59, 68, 63, 18, 80, 55, 64, 85,
#        73, 20, 74, 14, 82, 58, 10, 44, 15, 17, 81, 76, 56, 75, 54, 84, 16,
#        90, 79, 99, 77, 69,  2,  9,  4, 12, 72, 13, 88, 71,  8, 87,  6,  5,
#        11, 92, 94, 93,  3, 83, 89, 86, 91, 95, 97, 96, 98], dtype=int64)

# %%
df["Hour"] = df["DATETIME OCC"].dt.hour
df["Day of Week"] = df["DATETIME OCC"].dt.day_name()
df["Month"] = df["DATETIME OCC"].dt.month_name()

# %%
df
# Out:
#              DR_NO  Date Rptd   DATE OCC TIME OCC  AREA   AREA NAME  \
# 1        200106753 2020-02-09 2020-02-08     1800     1     Central
# 2        200320258 2020-11-11 2020-11-04     1700     3   Southwest
# 3        200907217 2023-05-10 2020-03-10     2037     9    Van Nuys
# 11       200406391 2020-03-02 2020-03-01     1430     4  Hollenbeck
# 19       200606074 2020-02-12 2020-02-07     1615     6   Hollywood
# ...            ...        ...        ...      ...   ...         ...
# 1004838  240119644 2024-10-04 2024-09-27     2345     1     Central
# 1004840  242011172 2024-08-20 2024-08-17     2300    20     Olympic
# 1004841  241414280 2024-10-16 2024-10-16     1546    14     Pacific
# 1004844  240410786 2024-10-14 2024-10-11     2330     4  Hollenbeck
# 1004845  240309674 2024-04-24 2024-04-24     1500     3   Southwest
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 1                182         1     330
# 2                356         1     480
# ...

# %% [markdown]
# VISUALIZATION

# %%
ncoa=df['AREA NAME'].value_counts()
ncoa
# Out:
# AREA NAME
# Central        52097
# Southwest      47805
# 77th Street    46209
# Pacific        42247
# Hollywood      39298
# Southeast      36521
# N Hollywood    36158
# Olympic        36110
# Wilshire       35768
# Topanga        34375
# Newton         33394
# Van Nuys       33388
# West LA        33162
# Rampart        33036
# West Valley    30914
# Mission        30139
# Northeast      29374
# Devonshire     29172
# Harbor         27726
# Foothill       24558
# Hollenbeck     24111
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.pie(ncoa.values, labels=ncoa.index, autopct='%1.1f%%', colors=['pink','red','blue','purple','gold'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["Year-Month"] = df["DATETIME OCC"].dt.to_period("M").astype(str)
plt.figure(figsize=(12,6))
sns.lineplot(data=df["Year-Month"].value_counts().sort_index(), marker="o")

plt.title("Crime Trend Over Time")
plt.xlabel("Month-Year")
plt.ylabel("Number of Crimes")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df["Hour"].value_counts().index, y=df["Hour"].value_counts().values, palette="coolwarm")

plt.title("Crimes by Hour of the Day")
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Crimes")
plt.xticks(range(0,24))
plt.grid(axis="y")
plt.show()

# %%
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
plt.figure(figsize=(12,6))
sns.barplot(x=df["Day of Week"].value_counts().reindex(day_order).index,
            y=df["Day of Week"].value_counts().reindex(day_order).values, palette="viridis")

plt.title("Crimes by Day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Number of Crimes")
plt.grid(axis="y")
plt.show()

# %%
month_order = ["January", "February", "March", "April", "May", "June",
               "July", "August", "September", "October", "November", "December"]

plt.figure(figsize=(12,6))
sns.barplot(x=df["Month"].value_counts().reindex(month_order).index,
            y=df["Month"].value_counts().reindex(month_order).values, palette="magma")

plt.title("Crimes by Month")
plt.xlabel("Month")
plt.ylabel("Number of Crimes")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=df["Crm Cd Desc"].value_counts().nlargest(10).index, 
            x=df["Crm Cd Desc"].value_counts().nlargest(10).values, palette="Blues_r")

plt.title("Top 10 Most Common Crimes")
plt.xlabel("Number of Crimes")
plt.ylabel("Crime Type")
plt.grid(axis="x")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df["Vict Age"], bins=30, kde=True, color="green")

plt.title("Distribution of Victim Ages")
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data= df, x="Vict Age")

plt.title("Distribution of Victim Ages")
plt.xlabel("Age")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=df["Premis Desc"].value_counts().nlargest(10).index, 
            x=df["Premis Desc"].value_counts().nlargest(10).values, palette="rocket")

plt.title("Top 10 Locations of Crimes")
plt.xlabel("Number of Crimes")
plt.ylabel("Premises Type")
plt.grid(axis="x")
plt.show()

# %%
weapon_counts = df["Weapon Desc"].value_counts().nlargest(5)
plt.figure(figsize=(8,8))
plt.pie(weapon_counts, labels=weapon_counts.index, autopct="%1.1f%%", colors=sns.color_palette("pastel"))

plt.title("Crimes Involving Weapons")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x=df["Part 1-2"], palette="coolwarm")

plt.title("Distribution of Part 1 and Part 2 Crimes")
plt.xlabel("Crime Category")
plt.ylabel("Number of Crimes")
plt.xticks(ticks=[0,1], labels=["Part 1 (Serious Crimes)", "Part 2 (Less Serious Crimes)"])
plt.grid(axis="y")

plt.show()

# %% [markdown]
# MACHINE LEARNING
